# %%
x = 2
type(x)
# Out:
# int

# %%
if x > 18:
    print('adult')
else :
    print('kid')
# Out:
# kid

# %%
for i in range(x):
    print(i)
# Out:
# 0
# 1

# %%
def green(num):
    return 'boom ' + num

print(green('44'))
# Out:
# boom 44
