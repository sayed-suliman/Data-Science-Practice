# %%
x = 2
type(x)
# Out:
# int

# %%
if x > 18:
    print('adult')
else :
    print('kid')
# Out:
# kid

# %%
for i in range(x):
    print(i)
# Out:
# 0
# 1

# %%
def green(num):
    return 'boom ' + num

print(green('44'))
# Out:
# boom 44

# %%
x = 4
4%2 == 0
# Out:
# True

# %%
x = 2
print(x/4)
# Out:
# 0.5

# %%
x = 3
if x % 3 == 1:
    print('here it is 3')
else:
    print('nothing')
# Out:
# nothing

# %%
# practice on dataframe
import pandas as pd

data = {
    'group': ['fruit', 'fruit', 'fruit', 'vegetable', 'vegetable', 'vegetable'],
    'name': ['apple', 'banana', 'orange', 'broccoli', 'kale', 'lettuce'],
    'count': [90, 150, 130, 80, 70, 125]
}
dt = {
    'hello':'green'
}
print(data)
df = pd.DataFrame(data)
print(df)
# Out:
# {'group': ['fruit', 'fruit', 'fruit', 'vegetable', 'vegetable', 'vegetable'], 'name': ['apple', 'banana', 'orange', 'broccoli', 'kale', 'lettuce'], 'count': [90, 150, 130, 80, 70, 125]}
#        group      name  count
# 0      fruit     apple     90
# 1      fruit    banana    150
# 2      fruit    orange    130
# 3  vegetable  broccoli     80
# 4  vegetable      kale     70
# 5  vegetable   lettuce    125

# %%
print(df['group'])
# Out:
# 0        fruit
# 1        fruit
# 2        fruit
# 3    vegetable
# 4    vegetable
# 5    vegetable
# Name: group, dtype: str

# %%
df[df['count'] > 100]
# Out:
#        group     name  count
# 1      fruit   banana    150
# 2      fruit   orange    130
# 5  vegetable  lettuce    125

# %%
datacamp = {
    'course': 'python',
    'level': 'intermediate',
    'lesson': {
        'dictionaries': 'python',
        'lists': 'something'
    }
}

datacamp['lesson']['list1'] = 'list 1'
pd.DataFrame(datacamp)
# Out:
#               course         level     lesson
# dictionaries  python  intermediate     python
# lists         python  intermediate  something
# list1         python  intermediate     list 1
