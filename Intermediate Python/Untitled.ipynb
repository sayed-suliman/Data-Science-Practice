# %%
range_nums = [1,24,5,234,52,3]
for i in range_nums:
    print(i+9)

print(range(9))
# Out:
# 10
# 33
# 14
# 243
# 61
# 12
# range(0, 9)

# %%
names = ["Ali", "Sara", "John"]

for name in names:
    print("Hello", name)
# Out:
# Hello Ali
# Hello Sara
# Hello John

# %%
data = [10, 20, 30, 40]
for eachdata in range(len(data)):
    print(eachdata , data[eachdata])
# Out:
# 0 10
# 1 20
# 2 30
# 3 40

# %%
years = [2021, 2021, 2022, 2022]
values = [100, 200, 300, 400]
for i in range(len(years)):
    year = years[i]
    
    if year == 2021:
        total = 1000
    else:
        total = 2000
        
    result = values[i] * total
    print(result)
# Out:
# 100000
# 200000
# 600000
# 800000

# %%
import pandas as pd

# Create sample dataset (like your project)
data = pd.DataFrame({
    'Date': ['2021-01-01', '2021-01-02', '2022-01-01'],
    'Price': [100, 150, 200],
    'Class': ['Y', 'J', 'Y'],
    'Region': ['Eur', 'Dom', 'Int']
})
print(data.head())
# Convert Date
data['Date'] = pd.to_datetime(data['Date'])

print(data)
# Out:
#          Date  Price Class Region
# 0  2021-01-01    100     Y    Eur
# 1  2021-01-02    150     J    Dom
# 2  2022-01-01    200     Y    Int
#         Date  Price Class Region
# 0 2021-01-01    100     Y    Eur
# 1 2021-01-02    150     J    Dom
# 2 2022-01-01    200     Y    Int

# %%
data
# Out:
#         Date  Price Class Region
# 0 2021-01-01    100     Y    Eur
# 1 2021-01-02    150     J    Dom
# 2 2022-01-01    200     Y    Int

# %%
print(data.loc[2,'Price'])
for i in range(len(data)):
    print(data.loc[i,'Price'])
# Out:
# 200
# 100
# 150
# 200

# %%
for index,row in data.iterrows():
    print(row['Region'])
# Out:
# Eur
# Dom
# Int
